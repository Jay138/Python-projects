# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
recent_grads=pd.read_csv("recent-grads.csv")
recent_grads.iloc[1]
recent_grads.head()
recent_grads.tail()
recent_grads.describe()
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  173.000000   173.000000     172.000000     172.000000     172.000000
# mean    87.000000  3879.815029   39370.081395   16723.406977   22646.674419
# std     50.084928  1687.753140   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.000000  2403.000000    4549.750000    2177.500000    1778.250000
# 50%     87.000000  3608.000000   15104.000000    5434.000000    8386.500000
# 75%    130.000000  5503.000000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size       Employed      Full_time      Part_time  \
# count  172.000000   173.000000     173.000000     173.000000     173.000000
# mean     0.522223   356.080925   31192.763006   26029.306358    8832.398844
# ...

# %%
recent_grads.iloc[1]
# Out:
# Rank                                                 2
# Major_code                                        2416
# Major                   MINING AND MINERAL ENGINEERING
# Total                                              756
# Men                                                679
# Women                                               77
# Major_category                             Engineering
# ShareWomen                                    0.101852
# Sample_size                                          7
# Employed                                           640
# Full_time                                          556
# Part_time                                          170
# Full_time_year_round                               388
# Unemployed                                          85
# Unemployment_rate                             0.117241
# Median                                           75000
# P25th                                            55000
# ...

# %%
recent_grads
# Out:
#      Rank  Major_code                                          Major  \
# 0       1        2419                          PETROLEUM ENGINEERING
# 1       2        2416                 MINING AND MINERAL ENGINEERING
# 2       3        2415                      METALLURGICAL ENGINEERING
# 3       4        2417      NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4       5        2405                           CHEMICAL ENGINEERING
# 5       6        2418                            NUCLEAR ENGINEERING
# 6       7        6202                              ACTUARIAL SCIENCE
# 7       8        5001                     ASTRONOMY AND ASTROPHYSICS
# 8       9        2414                         MECHANICAL ENGINEERING
# 9      10        2408                         ELECTRICAL ENGINEERING
# 10     11        2407                           COMPUTER ENGINEERING
# 11     12        2401                          AEROSPACE ENGINEERING
# 12     13        2404                         BIOMEDICAL ENGINEERING
# ...

# %%
raw_data_count=173

# %%
recent_grads.dropna()
# Out:
#      Rank  Major_code                                          Major  \
# 0       1        2419                          PETROLEUM ENGINEERING
# 1       2        2416                 MINING AND MINERAL ENGINEERING
# 2       3        2415                      METALLURGICAL ENGINEERING
# 3       4        2417      NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4       5        2405                           CHEMICAL ENGINEERING
# 5       6        2418                            NUCLEAR ENGINEERING
# 6       7        6202                              ACTUARIAL SCIENCE
# 7       8        5001                     ASTRONOMY AND ASTROPHYSICS
# 8       9        2414                         MECHANICAL ENGINEERING
# 9      10        2408                         ELECTRICAL ENGINEERING
# 10     11        2407                           COMPUTER ENGINEERING
# 11     12        2401                          AEROSPACE ENGINEERING
# 12     13        2404                         BIOMEDICAL ENGINEERING
# ...

# %%
cleaned_data_count=172

# %%
ax1=recent_grads.plot(x='Sample_size',y='Median',kind='scatter')

# %%
ax2=recent_grads.plot(x='Sample_size',y='Unemployment_rate',kind='scatter')

# %% [markdown]
# Sample_size vs Unemployment_rate plot does not show any specific trend. There is a signification decrease in the data with higher sample size. But from the plot above,we can comprehend that the mean unemployment rate did not change with increase in the sample size.

# %%
ax3=recent_grads.plot(x='Full_time',y='Median',kind='scatter')

# %%
recent_grads['Full_time']
# Out:
# 0        1849
# 1         556
# 2         558
# 3        1069
# 4       23170
# 5        2038
# 6        2924
# 7        1085
# 8       71298
# 9       55450
# 10      30315
# 11      11106
# 12       9017
# 13       2751
# 14       2999
# 15       5455
# 16      14879
# 17      41235
# 18       2277
# 19        808
# 20      91485
# 21       2558
# 22       7530
# 23       1658
# 24      15141
# 25      38302
# 26      15690
# 27       9639
# 28       6811
# 29       4163
#         ...
# 143      5798
# 144      4764
# 145    233205
# 146     29010
# 147     19420
# 148     13262
# 149     42764
# 150     36747
# 151     34941
# 152     14479
# 153      8447
# 154     11734
# 155      5201
# 156      6455
# 157      3565
# 158     18079
# 159     10451
# 160      7662
# 161      1098
# 162     20147
# 163     19975
# 164     27569
# 165      5197
# 166     25147
# 167     10121
# 168      5043
# 169      1848
# 170      1724
# 171      3154
# 172       593
# ...

# %% [markdown]
# As the number of FUll time increased, Median significantly dropped

# %%
ax3=recent_grads.plot(x='ShareWomen',y='Unemployment_rate',kind='scatter')

# %%
ax4=recent_grads.plot(x='Men',y='Median',kind='scatter')

# %%
ax5=recent_grads.plot(x='Women',y='Median',kind='scatter')

# %%
recent_grads['Sample_size'].hist(bins=5,range=(0,1000))

# %%
recent_grads['Sample_size']
# Out:
# 0        36
# 1         7
# 2         3
# 3        16
# 4       289
# 5        17
# 6        51
# 7        10
# 8      1029
# 9       631
# 10      399
# 11      147
# 12       79
# 13       22
# 14       30
# 15       55
# 16      183
# 17      425
# 18       26
# 19       14
# 20     1196
# 21       36
# 22       97
# 23       22
# 24      278
# 25      565
# 26      295
# 27      156
# 28      118
# 29       55
#        ...
# 143     110
# 144      59
# 145    2584
# 146     419
# 147     259
# 148     204
# 149     623
# 150     518
# 151     374
# 152     255
# 153     132
# 154     142
# 155      60
# 156      89
# 157      49
# 158     310
# 159     182
# 160     117
# 161      24
# 162     247
# 163      95
# 164     342
# 165      56
# 166     357
# 167     151
# 168      47
# 169       7
# 170      13
# 171      21
# 172       2
# Name: Sample_size, dtype: int64

# %%
recent_grads['Median'].hist(bins=10,range=(20000,75000))

# %% [markdown]
# From the histogram, median salary is found out to be around 35000

# %%
recent_grads['Employed'].hist(bins=20,range=(10000,200000))

# %%
recent_grads['Full_time'].hist(bins=20,range=(1000,10000))

# %%
recent_grads['Men'].hist(bins=50,range=(1000,150000))

# %%
from pandas.tools.plotting import scatter_matrix

# %%
scatter_matrix(recent_grads[['Sample_size','Median']],figsize=(5,5))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fb36cbccf60>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb36cb47978>]], dtype=object)

# %%
scatter_matrix(recent_grads[['Sample_size','Median','Unemployment_rate']],figsize=(5,5))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fb36ca6dda0>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb36c7c60b8>]], dtype=object)

# %%
x=len(recent_grads['ShareWomen'])
x
# Out:
# 173

# %%
recent_grads[:10].plot(x='Major',y='ShareWomen',kind='bar')

# %%
recent_grads[x-10:x].plot(x='Major',y='ShareWomen',kind='bar')
